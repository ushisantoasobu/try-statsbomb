# %%
import numpy as np
import pandas as pd

# match/16/22.json
# 
with open("./data/events/18236.json") as datafile:
  data = json.load(datafile)
dataframe = pd.DataFrame(data)

# %%
# カラム省略表記されてしまうので
pd.set_option('display.max_columns', 100)

# %%
dataframe
# Out:
#                                         id  index  period     timestamp  \
# 0     8eb54fd1-3b77-4de8-a6eb-63cb080010e7      1       1  00:00:00.000
# 1     dc677ade-3585-44c9-a377-c795a65c6310      2       1  00:00:00.000
# 2     de4c3384-3748-46b1-b6f0-6d7fd5ed41ab      3       1  00:00:00.000
# 3     206bb9ff-6848-4c98-8b81-797aaf24192b      4       1  00:00:00.000
# 4     a10ce602-229f-4c8a-8c61-95f8e7438a4a      5       1  00:00:01.213
# ...                                    ...    ...     ...           ...
# 4321  5aa430c2-2d96-472b-8e5e-abaf0127184a   4322       2  00:47:56.622
# 4322  073d145a-d793-40b1-8be9-587c84e16a28   4323       2  00:47:56.622
# 4323  9d814a56-cafc-49ac-b375-6e089236e065   4324       2  00:48:01.843
# 4324  c4f738ea-1af5-4694-9264-40e35ac7972c   4325       2  00:48:04.347
# 4325  f1c9fc85-e2ce-4fbc-947b-9b5d26cd7821   4326       2  00:48:04.347
#
#       minute  second                                 type  possession  \
# 0          0       0    {'id': 35, 'name': 'Starting XI'}           1
# 1          0       0    {'id': 35, 'name': 'Starting XI'}           1
# 2          0       0     {'id': 18, 'name': 'Half Start'}           1
# 3          0       0     {'id': 18, 'name': 'Half Start'}           1
# 4          0       1           {'id': 30, 'name': 'Pass'}           2
# ...      ...     ...                                  ...         ...
# 4321      92      56  {'id': 42, 'name': 'Ball Receipt*'}         195
# 4322      92      56          {'id': 43, 'name': 'Carry'}         195
# 4323      93       1           {'id': 30, 'name': 'Pass'}         195
# 4324      93       4       {'id': 34, 'name': 'Half End'}         195
# 4325      93       4       {'id': 34, 'name': 'Half End'}         195
#
#                               possession_team  \
# 0            {'id': 217, 'name': 'Barcelona'}
# 1            {'id': 217, 'name': 'Barcelona'}
# 2            {'id': 217, 'name': 'Barcelona'}
# 3            {'id': 217, 'name': 'Barcelona'}
# 4     {'id': 39, 'name': 'Manchester United'}
# ...                                       ...
# 4321         {'id': 217, 'name': 'Barcelona'}
# 4322         {'id': 217, 'name': 'Barcelona'}
# 4323         {'id': 217, 'name': 'Barcelona'}
# 4324         {'id': 217, 'name': 'Barcelona'}
# 4325         {'id': 217, 'name': 'Barcelona'}
#
#                             play_pattern  \
# 0      {'id': 1, 'name': 'Regular Play'}
# 1      {'id': 1, 'name': 'Regular Play'}
# 2      {'id': 1, 'name': 'Regular Play'}
# 3      {'id': 1, 'name': 'Regular Play'}
# 4     {'id': 9, 'name': 'From Kick Off'}
# ...                                  ...
# 4321   {'id': 1, 'name': 'Regular Play'}
# 4322   {'id': 1, 'name': 'Regular Play'}
# 4323   {'id': 1, 'name': 'Regular Play'}
# 4324   {'id': 1, 'name': 'Regular Play'}
# 4325   {'id': 1, 'name': 'Regular Play'}
#
#                                          team  duration  \
# 0            {'id': 217, 'name': 'Barcelona'}  0.000000
# 1     {'id': 39, 'name': 'Manchester United'}  0.000000
# 2     {'id': 39, 'name': 'Manchester United'}  0.000000
# 3            {'id': 217, 'name': 'Barcelona'}  0.000000
# 4     {'id': 39, 'name': 'Manchester United'}  0.580900
# ...                                       ...       ...
# 4321  {'id': 39, 'name': 'Manchester United'}       NaN
# 4322  {'id': 39, 'name': 'Manchester United'}  5.220500
# 4323  {'id': 39, 'name': 'Manchester United'}  2.325477
# 4324  {'id': 39, 'name': 'Manchester United'}  0.000000
# 4325         {'id': 217, 'name': 'Barcelona'}  0.000000
#
#                                                 tactics  \
# 0     {'formation': 41221, 'lineup': [{'player': {'i...
# 1     {'formation': 4222, 'lineup': [{'player': {'id...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4321                                                NaN
# 4322                                                NaN
# 4323                                                NaN
# 4324                                                NaN
# 4325                                                NaN
#
#                                          related_events  \
# 0                                                   NaN
# 1                                                   NaN
# 2                [206bb9ff-6848-4c98-8b81-797aaf24192b]
# 3                [de4c3384-3748-46b1-b6f0-6d7fd5ed41ab]
# 4                [ee82dbf9-b9f5-4eea-84f1-e243d1e97f51]
# ...                                                 ...
# 4321             [a690ea94-d105-4ea8-8e7b-9bd3fb3730f6]
# 4322  [5aa430c2-2d96-472b-8e5e-abaf0127184a, 9d814a5...
# 4323                                                NaN
# 4324             [f1c9fc85-e2ce-4fbc-947b-9b5d26cd7821]
# 4325             [c4f738ea-1af5-4694-9264-40e35ac7972c]
#
#                                                  player  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     {'id': 3058, 'name': 'Javier Hernández Balcázar'}
# ...                                                 ...
# 4321         {'id': 15036, 'name': 'Edwin van der Sar'}
# 4322         {'id': 15036, 'name': 'Edwin van der Sar'}
# 4323         {'id': 15036, 'name': 'Edwin van der Sar'}
# 4324                                                NaN
# 4325                                                NaN
#
#                                        position      location  \
# 0                                           NaN           NaN
# 1                                           NaN           NaN
# 2                                           NaN           NaN
# 3                                           NaN           NaN
# 4     {'id': 24, 'name': 'Left Center Forward'}  [61.0, 41.0]
# ...                                         ...           ...
# 4321            {'id': 1, 'name': 'Goalkeeper'}   [2.0, 24.0]
# 4322            {'id': 1, 'name': 'Goalkeeper'}   [2.0, 24.0]
# 4323            {'id': 1, 'name': 'Goalkeeper'}  [14.0, 29.0]
# 4324                                        NaN           NaN
# 4325                                        NaN           NaN
#
#                                                    pass  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     {'recipient': {'id': 3538, 'name': 'Wayne Mark...
# ...                                                 ...
# 4321                                                NaN
# 4322                                                NaN
# 4323  {'length': 53.235325, 'angle': 0.09406123, 'he...
# 4324                                                NaN
# 4325                                                NaN
#
#                                carry ball_receipt under_pressure duel  \
# 0                                NaN          NaN            NaN  NaN
# 1                                NaN          NaN            NaN  NaN
# 2                                NaN          NaN            NaN  NaN
# 3                                NaN          NaN            NaN  NaN
# 4                                NaN          NaN            NaN  NaN
# ...                              ...          ...            ...  ...
# 4321                             NaN          NaN            NaN  NaN
# 4322  {'end_location': [14.0, 29.0]}          NaN            NaN  NaN
# 4323                             NaN          NaN            NaN  NaN
# 4324                             NaN          NaN            NaN  NaN
# 4325                             NaN          NaN            NaN  NaN
#
#      counterpress dribble interception shot goalkeeper off_camera clearance  \
# 0             NaN     NaN          NaN  NaN        NaN        NaN       NaN
# 1             NaN     NaN          NaN  NaN        NaN        NaN       NaN
# 2             NaN     NaN          NaN  NaN        NaN        NaN       NaN
# 3             NaN     NaN          NaN  NaN        NaN        NaN       NaN
# 4             NaN     NaN          NaN  NaN        NaN        NaN       NaN
# ...           ...     ...          ...  ...        ...        ...       ...
# 4321          NaN     NaN          NaN  NaN        NaN        NaN       NaN
# 4322          NaN     NaN          NaN  NaN        NaN        NaN       NaN
# 4323          NaN     NaN          NaN  NaN        NaN        NaN       NaN
# 4324          NaN     NaN          NaN  NaN        NaN        NaN       NaN
# 4325          NaN     NaN          NaN  NaN        NaN        NaN       NaN
#
#      ball_recovery foul_won block foul_committed substitution bad_behaviour
# 0              NaN      NaN   NaN            NaN          NaN           NaN
# 1              NaN      NaN   NaN            NaN          NaN           NaN
# 2              NaN      NaN   NaN            NaN          NaN           NaN
# 3              NaN      NaN   NaN            NaN          NaN           NaN
# 4              NaN      NaN   NaN            NaN          NaN           NaN
# ...            ...      ...   ...            ...          ...           ...
# 4321           NaN      NaN   NaN            NaN          NaN           NaN
# 4322           NaN      NaN   NaN            NaN          NaN           NaN
# 4323           NaN      NaN   NaN            NaN          NaN           NaN
# 4324           NaN      NaN   NaN            NaN          NaN           NaN
# 4325           NaN      NaN   NaN            NaN          NaN           NaN
#
# [4326 rows x 35 columns]

# %%
dataframe['timestamp']
# Out:
# 0       00:00:00.000
# 1       00:00:00.000
# 2       00:00:00.000
# 3       00:00:00.000
# 4       00:00:01.213
#             ...
# 4321    00:47:56.622
# 4322    00:47:56.622
# 4323    00:48:01.843
# 4324    00:48:04.347
# 4325    00:48:04.347
# Name: timestamp, Length: 4326, dtype: object

# %%
# パスだけで1/4以上を占める
# dataframe[dataframe['pass'].notnull()]

# %%
# それぞれのカラムでnanの数を求める
dataframe.notnull().sum()
# Out:
# id                 4326
# index              4326
# period             4326
# timestamp          4326
# minute             4326
# second             4326
# type               4326
# possession         4326
# possession_team    4326
# play_pattern       4326
# team               4326
# duration           3158
# tactics               8
# related_events     4188
# player             4308
# position           4308
# location           4304
# pass               1222
# carry              1085
# ball_receipt        135
# under_pressure      835
# duel                 55
# counterpress         97
# dribble              44
# interception         28
# shot                 26
# goalkeeper           29
# off_camera           35
# clearance             2
# ball_recovery        10
# foul_won              9
# block                 2
# foul_committed        4
# substitution          5
# bad_behaviour         1
# dtype: int64

# %%
# typeごとに集計してみた
type_name_list = dataframe['type'].map(lambda x: x['name'])
type_name_list.value_counts()

# typeカラムでのpassと、passのカラムが同じ数なので、passカラムそのままみちゃった方が良さそう
# Out:
# Pass                 1222
# Ball Receipt*        1168
# Carry                1085
# Pressure              389
# Ball Recovery          83
# Duel                   55
# Dribble                44
# Dribbled Past          34
# Goal Keeper            29
# Interception           28
# Block                  26
# Shot                   26
# Dispossessed           25
# Miscontrol             23
# Foul Committed         22
# Foul Won               22
# Clearance              17
# Tactical Shift          6
# Substitution            5
# Half End                4
# Half Start              4
# Shield                  3
# Starting XI             2
# Referee Ball-Drop       2
# Offside                 1
# Bad Behaviour           1
# Name: type, dtype: int64

# %%
pass_list = dataframe['pass'][dataframe['pass'].notnull()]
# print(pass_list[4])
# print(pass_list[7])
# print(pass_list[9])
# print(pass_list[11])
pass_list
# Out:
# 4       {'recipient': {'id': 3538, 'name': 'Wayne Mark...
# 7       {'recipient': {'id': 20175, 'name': 'Ryan Gigg...
# 11      {'recipient': {'id': 3267, 'name': 'Luis Anton...
# 13      {'recipient': {'id': 5503, 'name': 'Lionel And...
# 15      {'recipient': {'id': 5203, 'name': 'Sergio Bus...
#                               ...
# 4306    {'recipient': {'id': 4891, 'name': 'Ibrahim Af...
# 4309    {'recipient': {'id': 20125, 'name': 'Carles Pu...
# 4313    {'length': 19.0, 'angle': 0.0, 'height': {'id'...
# 4320    {'recipient': {'id': 15036, 'name': 'Edwin van...
# 4323    {'length': 53.235325, 'angle': 0.09406123, 'he...
# Name: pass, Length: 1222, dtype: object
