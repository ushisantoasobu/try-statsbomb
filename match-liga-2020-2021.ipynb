# %%
import numpy as np
import pandas as pd

# Liga 2020-2021
with open("./data/matches/11/90.json") as datafile:
    data = json.load(datafile)
df = pd.DataFrame(data)

# %%
pd.set_option('display.max_columns', 100)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   match_id           35 non-null     int64
#  1   match_date         35 non-null     object
#  2   kick_off           35 non-null     object
#  3   competition        35 non-null     object
#  4   season             35 non-null     object
#  5   home_team          35 non-null     object
#  6   away_team          35 non-null     object
#  7   home_score         35 non-null     int64
#  8   away_score         35 non-null     int64
#  9   match_status       35 non-null     object
#  10  match_status_360   35 non-null     object
#  11  last_updated       35 non-null     object
#  12  last_updated_360   35 non-null     object
#  13  metadata           35 non-null     object
#  14  match_week         35 non-null     int64
#  15  competition_stage  35 non-null     object
# ...

# %%
df.head(5)
# Out:
#    match_id  match_date      kick_off  \
# 0   3773369  2021-03-15  21:00:00.000
# 1   3773387  2021-05-11  22:00:00.000
# 2   3773372  2021-05-08  16:15:00.000
# 3   3773695  2021-05-02  21:00:00.000
# 4   3773586  2021-04-29  19:00:00.000
#
#                                          competition  \
# 0  {'competition_id': 11, 'country_name': 'Spain'...
# 1  {'competition_id': 11, 'country_name': 'Spain'...
# 2  {'competition_id': 11, 'country_name': 'Spain'...
# 3  {'competition_id': 11, 'country_name': 'Spain'...
# 4  {'competition_id': 11, 'country_name': 'Spain'...
#
#                                           season  \
# 0  {'season_id': 90, 'season_name': '2020/2021'}
# 1  {'season_id': 90, 'season_name': '2020/2021'}
# 2  {'season_id': 90, 'season_name': '2020/2021'}
# 3  {'season_id': 90, 'season_name': '2020/2021'}
# 4  {'season_id': 90, 'season_name': '2020/2021'}
#
#                                            home_team  \
# ...

# %%
normalized = pd.json_normalize(data)

# %%
normalized.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 42 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   match_id                        35 non-null     int64
#  1   match_date                      35 non-null     object
#  2   kick_off                        35 non-null     object
#  3   home_score                      35 non-null     int64
#  4   away_score                      35 non-null     int64
#  5   match_status                    35 non-null     object
#  6   match_status_360                35 non-null     object
#  7   last_updated                    35 non-null     object
#  8   last_updated_360                35 non-null     object
#  9   match_week                      35 non-null     int64
#  10  competition.competition_id      35 non-null     int64
#  11  competition.country_name        35 non-null     object
# ...

# %%
normalized.head(5)
# Out:
#    match_id  match_date      kick_off  home_score  away_score match_status  \
# 0   3773369  2021-03-15  21:00:00.000           4           1    available
# 1   3773387  2021-05-11  22:00:00.000           3           3    available
# 2   3773372  2021-05-08  16:15:00.000           0           0    available
# 3   3773695  2021-05-02  21:00:00.000           2           3    available
# 4   3773586  2021-04-29  19:00:00.000           1           2    available
#
#   match_status_360                last_updated            last_updated_360  \
# 0        available  2021-03-16T12:45:17.775814  2021-07-27T01:28:10.084649
# 1        available  2021-05-13T00:20:44.739341  2021-07-27T01:16:02.992919
# 2        available  2021-05-10T04:24:10.396826  2021-07-27T01:16:38.082497
# 3        available  2021-05-07T13:24:24.423335  2021-07-27T01:18:50.218008
# 4        available     2021-07-06T16:43:21.218  2021-07-27T01:19:41.897076
#
# ...

# %%
# 全部バルサの試合？？ -> そうぽい
normalized[(normalized['home_team.home_team_name'] != 'Barcelona') & (normalized['away_team.away_team_name'] != 'Barcelona')]
# Out:
# Empty DataFrame
# Columns: [match_id, match_date, kick_off, home_score, away_score, match_status, match_status_360, last_updated, last_updated_360, match_week, competition.competition_id, competition.country_name, competition.competition_name, season.season_id, season.season_name, home_team.home_team_id, home_team.home_team_name, home_team.home_team_gender, home_team.home_team_group, home_team.country.id, home_team.country.name, home_team.managers, away_team.away_team_id, away_team.away_team_name, away_team.away_team_gender, away_team.away_team_group, away_team.country.id, away_team.country.name, away_team.managers, metadata.data_version, metadata.shot_fidelity_version, metadata.xy_fidelity_version, competition_stage.id, competition_stage.name, stadium.id, stadium.name, stadium.country.id, stadium.country.name, referee.id, referee.name, referee.country.id, referee.country.name]
# Index: []
