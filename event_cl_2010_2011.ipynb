# %%
import numpy as np
import pandas as pd

# CL 2010/2011 final
with open("./data/events/18236.json") as datafile:
    data = json.load(datafile)
df = pd.DataFrame(data)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', None)

# %%
df.shape
# Out:
# (4326, 35)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4326 entries, 0 to 4325
# Data columns (total 35 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               4326 non-null   object
#  1   index            4326 non-null   int64
#  2   period           4326 non-null   int64
#  3   timestamp        4326 non-null   object
#  4   minute           4326 non-null   int64
#  5   second           4326 non-null   int64
#  6   type             4326 non-null   object
#  7   possession       4326 non-null   int64
#  8   possession_team  4326 non-null   object
#  9   play_pattern     4326 non-null   object
#  10  team             4326 non-null   object
#  11  duration         3158 non-null   float64
#  12  tactics          8 non-null      object
#  13  related_events   4188 non-null   object
#  14  player           4308 non-null   object
#  15  position         4308 non-null   object
#  16  location         4304 non-null   object
# ...

# %%
# eventの種別
pd.Series(df['type'].map(lambda x: x['name'])).value_counts()
# Out:
# Pass                 1222
# Ball Receipt*        1168
# Carry                1085
# Pressure              389
# Ball Recovery          83
# Duel                   55
# Dribble                44
# Dribbled Past          34
# Goal Keeper            29
# Interception           28
# Block                  26
# Shot                   26
# Dispossessed           25
# Miscontrol             23
# Foul Committed         22
# Foul Won               22
# Clearance              17
# Tactical Shift          6
# Substitution            5
# Half End                4
# Half Start              4
# Shield                  3
# Starting XI             2
# Referee Ball-Drop       2
# Offside                 1
# Bad Behaviour           1
# Name: type, dtype: int64

# %%
df.head()
# Out:
#                                      id  index  period     timestamp  minute  \
# 0  8eb54fd1-3b77-4de8-a6eb-63cb080010e7      1       1  00:00:00.000       0
# 1  dc677ade-3585-44c9-a377-c795a65c6310      2       1  00:00:00.000       0
# 2  de4c3384-3748-46b1-b6f0-6d7fd5ed41ab      3       1  00:00:00.000       0
# 3  206bb9ff-6848-4c98-8b81-797aaf24192b      4       1  00:00:00.000       0
# 4  a10ce602-229f-4c8a-8c61-95f8e7438a4a      5       1  00:00:01.213       0
#
#    second                               type  possession  \
# 0       0  {'id': 35, 'name': 'Starting XI'}           1
# 1       0  {'id': 35, 'name': 'Starting XI'}           1
# 2       0   {'id': 18, 'name': 'Half Start'}           1
# 3       0   {'id': 18, 'name': 'Half Start'}           1
# 4       1         {'id': 30, 'name': 'Pass'}           2
#
#                            possession_team  \
# 0         {'id': 217, 'name': 'Barcelona'}
# 1         {'id': 217, 'name': 'Barcelona'}
# ...

# %%
df.isna().sum()
# Out:
# id                    0
# index                 0
# period                0
# timestamp             0
# minute                0
# second                0
# type                  0
# possession            0
# possession_team       0
# play_pattern          0
# team                  0
# duration           1168
# tactics            4318
# related_events      138
# player               18
# position             18
# location             22
# pass               3104
# carry              3241
# ball_receipt       4191
# under_pressure     3491
# duel               4271
# counterpress       4229
# dribble            4282
# interception       4298
# shot               4300
# goalkeeper         4297
# off_camera         4291
# clearance          4324
# ball_recovery      4316
# foul_won           4317
# block              4324
# foul_committed     4322
# substitution       4321
# bad_behaviour      4325
# dtype: int64

# %%
df[df['shot'].notnull()].iloc[0]
# Out:
# id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    
# ...

# %%
# シュートの情報では、まわりの選手の立ち位置見たいなデータが取れる
df[df['shot'].notnull()]['shot'].iloc[0]
# Out:
# {'statsbomb_xg': 0.04244132,
#  'end_location': [104.0, 34.0],
#  'key_pass_id': '5ecd1637-4a9a-45c5-b92b-7d5179334b53',
#  'technique': {'id': 93, 'name': 'Normal'},
#  'outcome': {'id': 96, 'name': 'Blocked'},
#  'type': {'id': 87, 'name': 'Open Play'},
#  'body_part': {'id': 40, 'name': 'Right Foot'},
#  'freeze_frame': [{'location': [108.0, 25.0],
#    'player': {'id': 5506, 'name': 'Javier Alejandro Mascherano'},
#    'position': {'id': 3, 'name': 'Right Center Back'},
#    'teammate': False},
#   {'location': [120.0, 40.0],
#    'player': {'id': 20176, 'name': 'Víctor Valdés Arribas'},
#    'position': {'id': 1, 'name': 'Goalkeeper'},
#    'teammate': False},
#   {'location': [103.0, 25.0],
#    'player': {'id': 3538, 'name': 'Wayne Mark Rooney'},
#    'position': {'id': 22, 'name': 'Right Center Forward'},
#    'teammate': True},
#   {'location': [104.0, 44.0],
#    'player': {'id': 20177, 'name': 'Eric-Sylvain Bilal Abidal'},
#    'position': {'id': 6, 'name': 'Left Back'},
# ...

# %%
df[df['id'] == '79ccac38-c894-478d-9c82-4295da166ad1']
# Out:
#                                        id  index  period     timestamp  \
# 141  79ccac38-c894-478d-9c82-4295da166ad1    142       1  00:02:48.157
#
#      minute  second                               type  possession  \
# 141       2      48  {'id': 23, 'name': 'Goal Keeper'}          11
#
#                              possession_team  \
# 141  {'id': 39, 'name': 'Manchester United'}
#
#                           play_pattern                              team  \
# 141  {'id': 1, 'name': 'Regular Play'}  {'id': 217, 'name': 'Barcelona'}
#
#      duration tactics                          related_events  \
# 141       0.0     NaN  [e8bac22f-e886-4dc6-a15c-87132c905858]
#
#                                              player  \
# 141  {'id': 20176, 'name': 'Víctor Valdés Arribas'}
#
#                             position     location pass carry ball_receipt  \
# 141  {'id': 1, 'name': 'Goalkeeper'}  [1.0, 41.0]  NaN   NaN          NaN
#
# ...

# %%
df[df['id'] == 'f51a1eab-dab1-48bf-a161-34a3e04a21d5']
# Out:
#                                        id  index  period     timestamp  \
# 140  f51a1eab-dab1-48bf-a161-34a3e04a21d5    141       1  00:02:47.797
#
#      minute  second                        type  possession  \
# 140       2      47  {'id': 6, 'name': 'Block'}          11
#
#                              possession_team  \
# 140  {'id': 39, 'name': 'Manchester United'}
#
#                           play_pattern                              team  \
# 140  {'id': 1, 'name': 'Regular Play'}  {'id': 217, 'name': 'Barcelona'}
#
#      duration tactics                          related_events  \
# 140       0.0     NaN  [e8bac22f-e886-4dc6-a15c-87132c905858]
#
#                                             player  \
# 140  {'id': 5213, 'name': 'Gerard Piqué Bernabéu'}
#
#                                   position      location pass carry  \
# 140  {'id': 5, 'name': 'Left Center Back'}  [17.0, 47.0]  NaN   NaN
#
# ...

# %%
df[df['shot'].notnull()]['shot']
# Out:
# 139                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              {'statsbomb_xg': 0.04244132, 'end_location': [104.0, 34.0], 'key_pass_id': '5ecd1637-4a9a-45c5-b92b-7d5179334b53', 'technique': {'id': 93, 'name': 'Normal'}, 'outcome': {'id': 96, 'name': 'Blocked'}, 'type': {'id': 87, 'name': 'Open Play'}, 'body_part': {'id': 40, 'name': 'Right Foot'}, 'freeze_frame': [{'location': [108.0, 25.0], 'player': {'id': 5506, 'name': 'Javier Alejandro Mascherano'}, 'position': {'id': 3, 'name': 'Right Center Back'}, 'teammate': False}, {'location': [120.0, 40.0], 'play
# ...

# %%
# デュエル
df[df['duel'].notnull()].iloc[0]
# Out:
# id                                                        b361ce5e-74f8-4e8b-a37d-11deb526271d
# index                                                                                       25
# period                                                                                       1
# timestamp                                                                         00:00:33.092
# minute                                                                                       0
# second                                                                                      33
# type                                                                 {'id': 4, 'name': 'Duel'}
# possession                                                                                   3
# possession_team                                               {'id': 217, 'name': 'Barcelona'}
# play_pattern                                                {'id': 4, 'name': 'From Throw In'}
# ...

# %%
# 上のデュエルでの関連イベントの中身を見てみる。デュエルで奪われたeventぽいな
df[df['id'] == 'ac4089c5-8360-4f82-9222-765eb292b4df'].iloc[0]
# Out:
# id                          ac4089c5-8360-4f82-9222-765eb292b4df
# index                                                         24
# period                                                         1
# timestamp                                           00:00:33.092
# minute                                                         0
# second                                                        33
# type                           {'id': 3, 'name': 'Dispossessed'}
# possession                                                     3
# possession_team                 {'id': 217, 'name': 'Barcelona'}
# play_pattern                  {'id': 4, 'name': 'From Throw In'}
# team                            {'id': 217, 'name': 'Barcelona'}
# duration                                                     0.0
# tactics                                                      NaN
# related_events            [b361ce5e-74f8-4e8b-a37d-11deb526271d]
# ...

# %%
df[df['duel'].notnull()][['timestamp', 'duel', 'player', 'play_pattern']]
# Out:
#          timestamp  \
# 24    00:00:33.092
# 76    00:01:32.727
# 89    00:01:44.973
# 107   00:02:24.013
# 126   00:02:39.646
# 133   00:02:44.126
# 258   00:04:37.936
# 290   00:05:09.645
# 317   00:05:39.619
# 409   00:08:10.320
# 457   00:09:06.245
# 557   00:11:02.472
# 562   00:11:04.566
# 577   00:11:15.307
# 700   00:13:13.533
# 828   00:15:00.117
# 883   00:16:29.816
# 917   00:17:12.015
# 1073  00:20:02.793
# 1186  00:21:50.950
# 1195  00:22:00.271
# 1211  00:22:17.818
# 1366  00:24:22.324
# 1420  00:25:19.089
# 1472  00:26:14.245
# 1562  00:28:34.776
# 1664  00:30:23.183
# 1886  00:36:44.002
# 1925  00:37:20.182
# 2291  00:01:25.680
# 2359  00:03:13.987
# 2423  00:05:39.113
# 2546  00:07:33.412
# 2619  00:09:33.089
# 2695  00:11:14.180
# 2717  00:12:12.547
# 2755  00:14:00.120
# 2803  00:15:21.214
# 2862  00:17:23.394
# 2994  00:19:25.586
# 3074  00:21:09.151
# 3171  00:22:25.908
# 3290  00:26:05.549
# 3301  00:26:23.210
# 3313  00:26:32.982
# 3416  00:28:22.591
# ...
