# %%
import numpy as np
import pandas as pd

# CL 2010/2011 final
with open("./data/lineups/18236.json") as datafile:
    data = json.load(datafile)
df = pd.DataFrame(data)

# %%
pd.set_option('display.max_columns', 100)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   team_id    2 non-null      int64
#  1   team_name  2 non-null      object
#  2   lineup     2 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 176.0+ bytes

# %%
df.head()
# Out:
#    team_id          team_name  \
# 0       39  Manchester United
# 1      217          Barcelona
#
#                                               lineup
# 0  [{'player_id': 3058, 'player_name': 'Javier He...
# 1  [{'player_id': 3958, 'player_name': 'Pedro Eli...

# %%
len(df['lineup'][0])
# Out:
# 18

# %%
len(df['lineup'][1])
# Out:
# 18

# %%
team_0 = df.iloc[0]
team_0.lineup
# Out:
# [{'player_id': 3058,
#   'player_name': 'Javier Hernández Balcázar',
#   'player_nickname': None,
#   'jersey_number': 14,
#   'country': {'id': 147, 'name': 'Mexico'},
#   'cards': [],
#   'positions': [{'position_id': 24,
#     'position': 'Left Center Forward',
#     'from': '00:00',
#     'to': '45:00',
#     'from_period': 1,
#     'to_period': 2,
#     'start_reason': 'Starting XI',
#     'end_reason': 'Tactical Shift'},
#    {'position_id': 23,
#     'position': 'Center Forward',
#     'from': '45:00',
#     'to': None,
#     'from_period': 2,
#     'to_period': None,
#     'start_reason': 'Tactical Shift',
#     'end_reason': 'Final Whistle'}]},
#  {'player_id': 3267,
#   'player_name': 'Luis Antonio Valencia Mosquera',
#   'player_nickname': 'Antonio Valencia',
#   'jersey_number': 25,
#   'country': {'id': 65, 'name': 'Ecuador'},
#   'cards': [],
#   'positions': [{'position_id': 17,
#     'position': 'Right Wing',
#     'from': '00:00',
#     'to': '45:00',
# ...

# %%
team_0_lineup = pd.DataFrame(team_0.lineup)
team_0_lineup
# Out:
#     player_id                      player_name   player_nickname  \
# 0        3058        Javier Hernández Balcázar              None
# 1        3267   Luis Antonio Valencia Mosquera  Antonio Valencia
# 2        3538                Wayne Mark Rooney      Wayne Rooney
# 3        4022                  Darren Fletcher              None
# 4        4751                  Michael Carrick              None
# 5        8281     Luís Carlos Almeida da Cunha              Nani
# 6       10958                   Chris Smalling              None
# 7       15036                Edwin van der Sar              None
# 8       15665                     Michael Owen              None
# 9       15666                     Paul Scholes              None
# 10      18239           Fábio Pereira da Silva             Fábio
# 11      20008                     Patrice Evra              None
# 12      20171                    Rio Ferdinand              None
# ...

# %%
len(team_0_lineup['positions'][0])
# Out:
# 2

# %%
for column_name, item in team_0_lineup.iteritems():
    if column_name == 'positions':
        for positions in item:
            print(len(positions))
# Out:
# 2
# 3
# 2
# 0
# 2
# 2
# 0
# 1
# 0
# 1
# 1
# 1
# 1
# 1
# 3
# 3
# 0
# 0

# %%
team_1 = df.iloc[1]
team_1_lineup = pd.DataFrame(team_1.lineup)
for column_name, item in team_1_lineup.iteritems():
    if column_name == 'positions':
        for positions in item:
            print(len(positions))
# Out:
# 2
# 1
# 1
# 0
# 1
# 0
# 1
# 1
# 2
# 3
# 0
# 2
# 3
# 1
# 2
# 1
# 1
# 0

# %%
# ポジション数をカラムに追加してみる
team_0_lineup['position_count'] = team_0_lineup['positions'].map(lambda x: len(x))
team_1_lineup['position_count'] = team_1_lineup['positions'].map(lambda x: len(x))

# %%
team_0_lineup
# Out:
#     player_id                      player_name   player_nickname  \
# 0        3058        Javier Hernández Balcázar              None
# 1        3267   Luis Antonio Valencia Mosquera  Antonio Valencia
# 2        3538                Wayne Mark Rooney      Wayne Rooney
# 3        4022                  Darren Fletcher              None
# 4        4751                  Michael Carrick              None
# 5        8281     Luís Carlos Almeida da Cunha              Nani
# 6       10958                   Chris Smalling              None
# 7       15036                Edwin van der Sar              None
# 8       15665                     Michael Owen              None
# 9       15666                     Paul Scholes              None
# 10      18239           Fábio Pereira da Silva             Fábio
# 11      20008                     Patrice Evra              None
# 12      20171                    Rio Ferdinand              None
# ...

# %%
team_1_lineup
# Out:
#     player_id                      player_name    player_nickname  \
# 0        3958  Pedro Eliezer Rodríguez Ledesma              Pedro
# 1        4324            Daniel Alves da Silva         Dani Alves
# 2        4891                  Ibrahim Afellay               None
# 3        4913                Bojan Krkíc Pérez              Bojan
# 4        5203         Sergio Busquets i Burgos    Sergio Busquets
# 5        5208   Thiago Alcântara do Nascimento   Thiago Alcântara
# 6        5213            Gerard Piqué Bernabéu       Gerard Piqué
# 7        5216             Andrés Iniesta Luján     Andrés Iniesta
# 8        5503   Lionel Andrés Messi Cuccittini       Lionel Messi
# 9        5506      Javier Alejandro Mascherano  Javier Mascherano
# 10       6692            Oier Olazábal Paredes      Oier Olazábal
# 11      12737              David Villa Sánchez        David Villa
# 12      20125         Carles Puyol i Saforcada       Carles Puyol
# ...

# %%
# マスチェラーノは終盤の2minだけ右サイドバックをやっている...はて？？
team_1_lineup.iloc[9].positions
# Out:
# [{'position_id': 3,
#   'position': 'Right Center Back',
#   'from': '00:00',
#   'to': '87:48',
#   'from_period': 1,
#   'to_period': 2,
#   'start_reason': 'Starting XI',
#   'end_reason': 'Tactical Shift'},
#  {'position_id': 2,
#   'position': 'Right Back',
#   'from': '87:48',
#   'to': '89:50',
#   'from_period': 2,
#   'to_period': 2,
#   'start_reason': 'Tactical Shift',
#   'end_reason': 'Tactical Shift'},
#  {'position_id': 3,
#   'position': 'Right Center Back',
#   'from': '89:50',
#   'to': None,
#   'from_period': 2,
#   'to_period': None,
#   'start_reason': 'Tactical Shift',
#   'end_reason': 'Final Whistle'}]

# %%
# プジョルとなんか入れ替わってるな、、、どういうことだろう？？
team_1_lineup.iloc[12].positions
# Out:
# [{'position_id': 2,
#   'position': 'Right Back',
#   'from': '87:47',
#   'to': '87:48',
#   'from_period': 2,
#   'to_period': 2,
#   'start_reason': 'Substitution - On (Tactical)',
#   'end_reason': 'Tactical Shift'},
#  {'position_id': 3,
#   'position': 'Right Center Back',
#   'from': '87:48',
#   'to': '89:50',
#   'from_period': 2,
#   'to_period': 2,
#   'start_reason': 'Tactical Shift',
#   'end_reason': 'Tactical Shift'},
#  {'position_id': 2,
#   'position': 'Right Back',
#   'from': '89:50',
#   'to': None,
#   'from_period': 2,
#   'to_period': None,
#   'start_reason': 'Tactical Shift',
#   'end_reason': 'Final Whistle'}]
