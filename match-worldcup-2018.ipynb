# %%
import numpy as np
import pandas as pd

# World Cup 2018
with open("./data/matches/43/3.json") as datafile:
    data = json.load(datafile)
df = pd.DataFrame(data)

# %%
# 全試合ぽい :cool:
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   match_id           64 non-null     int64
#  1   match_date         64 non-null     object
#  2   kick_off           64 non-null     object
#  3   competition        64 non-null     object
#  4   season             64 non-null     object
#  5   home_team          64 non-null     object
#  6   away_team          64 non-null     object
#  7   home_score         64 non-null     int64
#  8   away_score         64 non-null     int64
#  9   match_status       64 non-null     object
#  10  match_status_360   64 non-null     object
#  11  last_updated       64 non-null     object
#  12  last_updated_360   64 non-null     object
#  13  metadata           64 non-null     object
#  14  match_week         64 non-null     int64
#  15  competition_stage  64 non-null     object
# ...

# %%
df.head()
# Out:
#    match_id  match_date      kick_off  \
# 0      7578  2018-06-15  14:00:00.000
# 1      7553  2018-06-23  17:00:00.000
# 2      7544  2018-06-20  17:00:00.000
# 3      7536  2018-06-18  17:00:00.000
# 4      7555  2018-06-24  20:00:00.000
#
#                                          competition  \
# 0  {'competition_id': 43, 'country_name': 'Intern...
# 1  {'competition_id': 43, 'country_name': 'Intern...
# 2  {'competition_id': 43, 'country_name': 'Intern...
# 3  {'competition_id': 43, 'country_name': 'Intern...
# 4  {'competition_id': 43, 'country_name': 'Intern...
#
#                                     season  \
# 0  {'season_id': 3, 'season_name': '2018'}
# 1  {'season_id': 3, 'season_name': '2018'}
# 2  {'season_id': 3, 'season_name': '2018'}
# 3  {'season_id': 3, 'season_name': '2018'}
# 4  {'season_id': 3, 'season_name': '2018'}
#
#                                            home_team  \
# 0  {'home_team_id': 774, 'home_team_name': 'Egypt...
# ...
